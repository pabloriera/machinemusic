# %%
# %pylab inline
import pandas as pd
from sklearn import decomposition

# %run ../utils.py

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.linear_model import LogisticRegression
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# make 3-class dataset for classification
centers = [[10,5]]
X, y = make_blobs(n_samples=1000, centers=centers, random_state=40)
transformation = [[0.4, 0.2], [-0.4, 1.2]]
X = np.dot(X, transformation)
# plot(X[:,0],X[:,1],'.');
plot(X)
# Out:
# [<matplotlib.lines.Line2D at 0x7f16be91a2e8>,
#  <matplotlib.lines.Line2D at 0x7f16be91a438>]

# %%
XZCA = ZCA(regularization=0.01).fit(X).transform(X)
# plot(XZCA[:,0],XZCA[:,1],'.');
plot(XZCA)
# Out:
# [<matplotlib.lines.Line2D at 0x7f16be9ea2e8>,
#  <matplotlib.lines.Line2D at 0x7f16be9ea438>]

# %%
Xnorm = normalize(X,white=False)
# plot(Xnorm[:,0],Xnorm[:,1],'.');
plot(Xnorm)
# Out:
# [<matplotlib.lines.Line2D at 0x7f16be9b76a0>,
#  <matplotlib.lines.Line2D at 0x7f16be9b77f0>]

# %%
Xnorm = normalize(X,white=True)
# plot(Xnorm[:,0],Xnorm[:,1],'.');
plot(Xnorm)
# Out:
# [<matplotlib.lines.Line2D at 0x7f16be89d1d0>,
#  <matplotlib.lines.Line2D at 0x7f16be89d320>]
