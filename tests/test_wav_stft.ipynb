# %%
import scipy as sp
import sounddevice as sd
import librosa
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sd.play(randn(1000)*0.2,samplerate=1000)

# %%
from scipy.io import wavfile

# %%
fs,x2 = wavfile.read("../wavs/guitar.wav")
x2 = np.float64(x2)/2**15
# Out:
# /usr/local/lib/python2.7/dist-packages/scipy/io/wavfile.py:221: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
#sd.play(x2,samplerate=fs)

# %%
x = x2[:,0]
D = librosa.stft(x,n_fft=1024)

# %%
# %matplotlib inline
imshow(log10(abs(D)),aspect='auto',origin="bottom")

# %%
D2 = librosa.cqt(x, real=False)
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/numeric.py:482: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return array(a, dtype, copy=False, order=order)

# %%
np.log2(fs/2)
2**14
14*24/2
# Out:
# 168

# %%
imshow(log10(abs(D2)),aspect='auto',origin="bottom")

# %%
fs/2
# Out:
# 22050

# %%
fs,x2 = wavfile.read("../wavs/uUu.wav")
print(x2.dtype)
x2 = np.float64(x2)/2**15
x = x2[:,0]
D = librosa.stft(x)#,n_fft=1024)
imshow(log10(abs(D)),aspect='auto',origin="bottom")
D2 = librosa.cqt(x,sr=fs, real=False,n_bins=220,bins_per_octave=24)
figure()

imshow(log10(abs(D2)),aspect='auto',origin="bottom")
# Out:
# int16

# %%
fs/2/D.shape[0]
# Out:
# 42
